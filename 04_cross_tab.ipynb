# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el dataset
cybersecurity_data = pd.read_csv('tmp/Ejemplo_02_03_Cybersecurity_Dataset.csv') 
cybersecurity_data.head()
# Out:
#    attack_type  severity  response_time
# 0   Ransomware         4            2.8
# 1  Brute Force         9           11.6
# 2      Malware         6            4.7
# 3  Brute Force         3            2.0
# 4  Brute Force         1            1.8

# %%
# Crear una tabla de informacion cruzada (num de incidentes por severidad y tipo de atque)
cross_data = pd.crosstab(cybersecurity_data['severity'], cybersecurity_data['attack_type'])
cross_data
# Out:
# attack_type  Brute Force  DDoS  Malware  Phishing  Ransomware
# severity
# 1                      8    13        6        13          15
# 2                      8     7        9        12           6
# 3                      6     8       17        10          12
# 4                     11     9        6         6          15
# 5                      8    11        8        17          14
# 6                     10    15        8         9          15
# 7                      7     2        4        13          13
# 8                      9     9       11        15           6
# 9                     12    10        9         8           7
# 10                    14    11       13         6           9

# %%
cross_data.plot(
    kind = 'bar',
    stacked = True,
    figsize = (10,6),
    colormap = 'viridis'
)

plt.title('num de incidentes por severidad y tipo de atque', fontsize=16)
plt.xlabel('Severidad del incidente', fontsize=14)
plt.ylabel('Numero de incidentes', fontsize=14)

plt.legend(title = 'attack_type', bbox_to_anchor=(1,1), loc='upper left')

plt.show()
